# %% [markdown]
# <a href="https://colab.research.google.com/github/Noorudinz/DataScience/blob/sampleBranch/sample_branch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt

x = [1,1.5,2,2.5,3]
y = [7,8,9,10.5,12]

plt.plot(y,x)

plt.title("Line graph")
plt.ylabel("Y axis")
plt.xlabel("X axis")
plt.show()
